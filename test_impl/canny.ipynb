# %%
import sys
sys.path.append("../src")

import edge_detectioin
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.append("../src")
# ----> 4 import edge_detectioin
#
# File e:\brand_detection\Brand-Detection\test_impl\../src\edge_detectioin.py:1
# ----> 1 import cv2
#       3 def canny_edge_detector(image, threshold1=50, threshold2=150):
#       4         """implement your solution and documnet this functoin"""
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
import matplotlib.pyplot as plt



image = cv2.imread("../Cloth/a1.png", cv2.IMREAD_GRAYSCALE)
edges1 = cv2.Canny(image, 50, 150)
edges2 = edge_detectioin.canny_edge_detector(image, 50, 150)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("cv2 Canny")
plt.imshow(edges1, cmap='gray')
plt.subplot(1,2,2)
plt.title("My Canny")
plt.imshow(edges2, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import cv2
#       2 import matplotlib.pyplot as plt
#       6 image = cv2.imread("../Cloth/a1.png", cv2.IMREAD_GRAYSCALE)
#
# ModuleNotFoundError: No module named 'cv2'
