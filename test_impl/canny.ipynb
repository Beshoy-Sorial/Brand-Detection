# %%
import sys
sys.path.append("../src")

import edge_detectioin

# %%
import cv2
import matplotlib.pyplot as plt



image = cv2.imread("../Cloth/a1.png", cv2.IMREAD_GRAYSCALE)
edges1 = cv2.Canny(image, 50, 150)
edges2 = edge_detectioin.canny_edge_detector(image, 50, 150)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("cv2 Canny")
plt.imshow(edges1, cmap='gray')
plt.subplot(1,2,2)
plt.title("My Canny")
plt.imshow(edges2, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 12
#      10 plt.subplot(1,2,1)
#      11 plt.title("cv2 Canny")
# ---> 12 plt.imshow(edges1, cmap='gray')
#      13 plt.subplot(1,2,2)
#      14 plt.title("My Canny")
#
# File c:\Users\cccxx\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3590, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3568 @_copy_docstring_and_deprecators(Axes.imshow)
#    3569 def imshow(
#    3570     X: ArrayLike | PIL.Image.Image,
#    (...)   3588     **kwargs,
#    3589 ) -> AxesImage:
# -> 3590     __ret = gca().imshow(
#    3591         X,
#    3592         cmap=cmap,
#    3593         norm=norm,
#    3594         aspect=aspect,
#    3595         interpolation=interpolation,
# ...
